# %%
import pandas as pd

# %%
pd.read_csv("https://raw.githubusercontent.com/Sud-Austral/Datos/master/Twitter/Tweet.csv").head(50)
# Out:
#                                             Contenido  \
# 0   RT @ministeriosalud: Conoce la campaña del @Mi...
# 1   RT @SeremiSaludRM: Respeta la cuarentena en tu...
# 2   Conoce más sobre esta nueva medida en https://...
# 3   RT @Colmedchillan: En más de alguna ocasión te...
# 4   RT @colmedtemuco: 📌Porque además de afectar nu...
# 5   [#Webinar] Si no pudiste ver nuestro #Seminari...
# 6   Protégete contra el nuevo Coronavirus COVID-19...
# 7   @ALEXIS_VASQUEZ @RedSaludCChC Hola, buenas noc...
# 8   RT @SeremiSaludRM: Este martes, nuestras ofici...
# 9   RT @EnnioVivaldi: Junto a @gblumel presentamos...
# 10  RT @matiasirad: Apoyamos el plan de #SaludMent...
# 11  RT @ceciliarod: Qué tremendo acuerdo! 👏🏻👏🏻👏🏻👏🏻...
# 12  RT @24HorasTVN: #ENVIVO | Fernando Leanes repr...
# 13  RT @ColMedValpo: Hoy a las 21:00 @dridelatorre...
# 14  ¡Házlas en tu casa! Con un pañuelo, dos elásti...
# 15  Valoramos dictamen de @SUSESOChile de hoy que ...
# ...

# %%
import hashlib

# %%
ola = "Hola wena wena wena \n asi tal cual"
#hash_object = hashlib.md5(ola.encode())
#hashlib.
#print(hash_object.hexdigest())

# %%
str(hash_object.hexdigest()).encode()
# Out:
# b'f688ae26e9cfa3ba6235477831d5122e'

# %%
ola.encode('ascii')
# Out:
# b'Hola'

# %%
aux = ''.join(format(ord(i), 'b') for i in ola)

# %%
def BinaryToDecimal(binary):  
         
    binary1 = binary  
    decimal, i, n = 0, 0, 0
    while(binary != 0):  
        dec = binary % 10
        decimal = decimal + dec * pow(2, i)  
        binary = binary//10
        i += 1
    return (decimal)  
str_data = ""
for i in range(0, len(aux), 7): 
      
    # slicing the bin_data from index range [0, 6] 
    # and storing it as integer in temp_data 
    temp_data = int(aux[i:i + 7]) 
       
    # passing temp_data in BinarytoDecimal() fuction 
    # to get decimal value of corresponding temp_data 
    decimal_data = BinaryToDecimal(temp_data) 
       
    # Deccoding the decimal value returned by  
    # BinarytoDecimal() function, using chr()  
    # function which return the string corresponding  
    # character for given ASCII value, and store it  
    # in str_data 
    str_data =  str_data +  chr(decimal_data)  
   
# printing the result 
print("The Binary value after string conversion is:",  
       str_data)
# Out:
# The Binary value after string conversion is: HolaAoK]C_;>.v
# ACgSS2.

# %%
import binascii
def to_hex(t, nbytes):
    """Format text t as a sequence of nbyte long values
    separated by spaces.
    """
    chars_per_item = nbytes * 2
    hex_version = binascii.hexlify(t)
    return b' '.join(
        hex_version[start:start + chars_per_item]
        for start in range(0, len(hex_version), chars_per_item)
    )

text = 'wena wena wena wena'
encoded = text.encode('utf-8')
decoded = encoded.decode('utf-8')

print('Original :', repr(text))
print('Encoded  :', to_hex(encoded, 1), type(encoded))
print('Decoded  :', repr(decoded), type(decoded))

print(to_hex(encoded, 1).decode('utf-8'))
# Out:
# Original : 'wena wena wena wena'
# Encoded  : b'77 65 6e 61 20 77 65 6e 61 20 77 65 6e 61 20 77 65 6e 61' <class 'bytes'>
# Decoded  : 'wena wena wena wena' <class 'str'>
