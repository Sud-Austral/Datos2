# %%
import pandas as pd

# %%
data = pd.read_html("https://www.emol.com/noticias/Economia/2020/03/27/981227/Despachos-a-domicilio-RM-2020.html")

# %%
for i in data:
    print(i)
# Out:
#                                0  \
# 0                  Agrícola Ocoa
# 1                Benicio Mercado
# 2                       Deli Veg
# 3                         DeCaba
# 4                  Dengo Gourmet
# 5                     DespachosR
# 6                  DeliveryProvi
# 7       Distribuidora Bahamondes
# 8                     El Negrito
# 9              Feria a Domicilio
# 10                Fresco&Natural
# 11                       Fresbox
# 12                     FruitShop
# 13                  Fruton Chile
# 14                 Huertas a Deo
# 15              Huertos del Chef
# 16                  La Biohuerta
# 17  La Estación Frutería Gourmet
# 18              La Feria Express
# 19                 La Frutología
# 20           La Reserva de Loyca
# 21           La Vega a Domicilio
# 22                     La Vegana
# 23                 Palta Express
# 24                      Racofrut
# 25                 Tu Buen Sabor
# 26                Vasma Delivery
# ...
