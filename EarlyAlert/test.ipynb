# %%
import requests
import pandas as pd
import urllib.request
import codecs
import json

# %%
url = "https://kc.humanitarianresponse.info/api/v1/forms/520455.csv"

# %%
#response = requests.patch(url, auth=('sudaustral', 'Sudaustral2020+'))
response = requests.get(url, auth=('sudaustral', 'Sudaustral2020+'))
decoded_data = codecs.decode(response.content, 'utf-8-sig')
#print(response.content)
#print(decoded_data)
#salida = ""
#for i in decoded_data.split("\n"):
#    if(i != ""):
#        salida = salida + i + "\n"
#        #print(i)
#        #print("***************************")
#print(salida)    
archivo = open("hello.csv", "w") 
archivo.write(decoded_data) 
archivo.close() 
data = pd.read_csv("hello.csv")
data

#for i in response:
#    print(i)
# Out:
#                            start Registro_de_Instalaciones_Chile  \
# 0  2020-03-31T20:08:51.074-06:00                       Prueba AJ
# 1  2020-03-31T23:26:16.978-03:00                            test
# 2  2020-03-31T23:52:49.390-03:00                           test2
# 3  2020-03-31T23:53:24.155-03:00                           asdas
#
#   Nombre_de_la_Instalaci_n    Categor_a Subcategor_a  \
# 0            HospitaL NNNN        salud     Hospital
# 1                     test  residencial         test
# 2                    test2        salud         test
# 3                    asdas        salud        asdas
#
#                 Localizaci_n  _Localizaci_n_latitude  _Localizaci_n_longitude  \
# 0   13.707846 -89.255274 0 0               13.707846               -89.255274
# 1   -29.351525 -67.34514 0 0              -29.351525               -67.345140
# 2     9.864962 11.454764 0 0                9.864962                11.454764
# 3  -11.109411 -70.159422 0 0              -11.109411               -70.159422
#
#    _Localizaci_n_altitude  _Localizaci_n_precision             __version__  \
# 0                       0                        0  vLwquML7EthUDwVLVUmLqJ
# 1                       0                        0  vLwquML7EthUDwVLVUmLqJ
# 2                       0                        0  vLwquML7EthUDwVLVUmLqJ
# 3                       0                        0  vLwquML7EthUDwVLVUmLqJ
#
#                              meta/instanceID  \
# 0  uuid:58a8c06f-d627-49e6-99aa-7d3969191b07
# 1  uuid:271776a1-6433-439c-9d8b-90030f388550
# 2  uuid:9c82a144-907b-4406-b0cd-d09f2c0949e2
# 3  uuid:8040486b-2696-4950-8c60-d8854450af78
#
#                                   _uuid     _submission_time  _tags  _notes
# 0  58a8c06f-d627-49e6-99aa-7d3969191b07  2020-04-01T02:11:00    NaN     NaN
# 1  271776a1-6433-439c-9d8b-90030f388550  2020-04-01T02:27:10    NaN     NaN
# 2  9c82a144-907b-4406-b0cd-d09f2c0949e2  2020-04-01T02:53:29    NaN     NaN
# 3  8040486b-2696-4950-8c60-d8854450af78  2020-04-01T02:59:36    NaN     NaN

# %%
#url = 'http://i3.ytimg.com/vi/J---aiyznGQ/mqdefault.jpg'
urllib.request.urlretrieve(url, 'ola.csv', auth=('sudaustral', 'Sudaustral2020+'))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-48-d3f6319572be> in <module>
#       1 #url = 'http://i3.ytimg.com/vi/J---aiyznGQ/mqdefault.jpg'
# ----> 2 urllib.request.urlretrieve(url, 'ola.csv', auth=('sudaustral', 'Sudaustral2020+'))
#
# TypeError: urlretrieve() got an unexpected keyword argument 'auth'

# %%
data = pd.read_csv("hola.csv")
data
# Out:
#                            start Registro_de_Instalaciones_Chile  \
# 0  2020-03-31T20:08:51.074-06:00                       Prueba AJ
# 1  2020-03-31T23:26:16.978-03:00                            test
# 2  2020-03-31T23:52:49.390-03:00                           test2
# 3  2020-03-31T23:53:24.155-03:00                           asdas
#
#   Nombre_de_la_Instalaci_n    Categor_a Subcategor_a  \
# 0            HospitaL NNNN        salud     Hospital
# 1                     test  residencial         test
# 2                    test2        salud         test
# 3                    asdas        salud        asdas
#
#                 Localizaci_n  _Localizaci_n_latitude  _Localizaci_n_longitude  \
# 0   13.707846 -89.255274 0 0               13.707846               -89.255274
# 1   -29.351525 -67.34514 0 0              -29.351525               -67.345140
# 2     9.864962 11.454764 0 0                9.864962                11.454764
# 3  -11.109411 -70.159422 0 0              -11.109411               -70.159422
#
#    _Localizaci_n_altitude  _Localizaci_n_precision             __version__  \
# 0                       0                        0  vLwquML7EthUDwVLVUmLqJ
# 1                       0                        0  vLwquML7EthUDwVLVUmLqJ
# 2                       0                        0  vLwquML7EthUDwVLVUmLqJ
# 3                       0                        0  vLwquML7EthUDwVLVUmLqJ
#
#                              meta/instanceID  \
# 0  uuid:58a8c06f-d627-49e6-99aa-7d3969191b07
# 1  uuid:271776a1-6433-439c-9d8b-90030f388550
# 2  uuid:9c82a144-907b-4406-b0cd-d09f2c0949e2
# 3  uuid:8040486b-2696-4950-8c60-d8854450af78
#
#                                   _uuid     _submission_time  _tags  _notes
# 0  58a8c06f-d627-49e6-99aa-7d3969191b07  2020-04-01T02:11:00    NaN     NaN
# 1  271776a1-6433-439c-9d8b-90030f388550  2020-04-01T02:27:10    NaN     NaN
# 2  9c82a144-907b-4406-b0cd-d09f2c0949e2  2020-04-01T02:53:29    NaN     NaN
# 3  8040486b-2696-4950-8c60-d8854450af78  2020-04-01T02:59:36    NaN     NaN
