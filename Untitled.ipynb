# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
import time
import requests
import json  
import codecs
import pandas as pd
import os
import shutil
from datetime import datetime, timedelta, date
from selenium.webdriver.firefox.firefox_profile import FirefoxProfile
from selenium.webdriver.firefox.options import Options
from os import remove
import git
import datetime
import numpy as np

def verificarColumnas(data, referencia):
    ruta = "GrupoControl/"
    df = data
    ref = pd.read_csv(ruta + referencia)
    existe = False
    columna = 0    
    #Eliminar Columnas que sobran    
    for col in df.columns:        
        for colRef in ref.columns:
            if col == colRef:
                #print("existe la columna" + col)
                existe = True
        if existe == False:
            del df[col]
            #df.to_csv(csvPorVerificar, index = False)
            print("se Eliminó la columna " + col)
        existe = False   
    #Agregar columnas faltantes    
    for colRef in ref.columns:        
        for col in df.columns:
            if col == colRef:
                #print("existe la columna" + col)
                existe = True
        if existe == False:
            df.insert(columna,colRef,'')
            #df.to_csv(csvPorVerificar, index = False)
            print("se agregó la columna " + colRef)
        columna+=1
        existe = False
    return df

# %%
url  = 'https://services9.arcgis.com/Rha9bYQCF0JEy8bJ/ArcGIS/rest/services/Current_Coronavirus_Cases_and_Deaths/FeatureServer/0/1?f=pjson'
response = requests.get(url)
decoded_data=codecs.decode(response.content, 'utf-8-sig')
d = json.loads(decoded_data)
#print(d["feature"]["attributes"])
flag = True
n = 1
salida = []
while flag:
    try:
        url  = 'https://services9.arcgis.com/Rha9bYQCF0JEy8bJ/ArcGIS/rest/services/Current_Coronavirus_Cases_and_Deaths/FeatureServer/0/'+str(n)+'?f=pjson'
        response = requests.get(url)
        decoded_data=codecs.decode(response.content, 'utf-8-sig')
        d = json.loads(decoded_data)
        #print(d["feature"]["attributes"])
        salida.append(d["feature"]["attributes"])
        n += 1
    except:
        flag = False
data = pd.DataFrame.from_dict(salida)

ola = verificarColumnas(data,"Current_Coronavirus_Cases_and_Deaths.csv")
ola
# Out:
# se Eliminó la columna NAME
# se Eliminó la columna COUNTRY
# se Eliminó la columna ISO_CODE
# se Eliminó la columna ISO_CC
# se Eliminó la columna ADMINTYPE
# se Eliminó la columna COUNTRYAFF
# se Eliminó la columna CONTINENT
# se Eliminó la columna LAND_TYPE
# se Eliminó la columna Confirmed
# se Eliminó la columna Deaths
# se Eliminó la columna x
# se Eliminó la columna y
# se Eliminó la columna ObjectId
# se agregó la columna dateRep
# se agregó la columna day
# se agregó la columna month
# se agregó la columna year
# se agregó la columna cases
# se agregó la columna deaths
# se agregó la columna countriesAndTerritories
# se agregó la columna geoId
# se agregó la columna countryterritoryCode
# se agregó la columna popData2018
#      dateRep day month year cases deaths countriesAndTerritories geoId  \
# 0
# 1
# 2
# 3
# 4
# ...      ...  ..   ...  ...   ...    ...                     ...   ...
# 5759
# 5760
# 5761
# 5762
# 5763
#
#      countryterritoryCode popData2018
# 0
# 1
# 2
# 3
# 4
# ...                   ...         ...
# 5759
# 5760
# 5761
# 5762
# 5763
#
# [5764 rows x 10 columns]

# %%
data
# Out:
#         ID       Fecha  Region_Numero   País        Region        Sexo  Edad  \
# 0        1  23-03-2020            1.0  Chile      Tarapacá   Masculino  47.0
# 1        2  23-03-2020            1.0  Chile      Tarapacá  Masculino   31.0
# 2        3  23-03-2020            1.0  Chile      Tarapacá    Femenino  55.0
# 3        4  23-03-2020            1.0  Chile      Tarapacá   Masculino  66.0
# 4        5  25-03-2020            1.0  Chile      Tarapacá   Masculino  36.0
# ...    ...         ...            ...    ...           ...         ...   ...
# 5567  5568  06-04-2020            NaN  Chile  No Informado         NaN   NaN
# 5568  5569  06-04-2020            NaN  Chile  No Informado         NaN   NaN
# 5569  5570  06-04-2020            NaN  Chile  No Informado         NaN   NaN
# 5570  5571  06-04-2020            NaN  Chile  No Informado         NaN   NaN
# 5571  5572  06-04-2020            NaN  Chile  No Informado         NaN   NaN
#
#      Centro_de_Salud        Comuna  lat  lon Tipo_de_caso  lat_comuna  \
# 0                NaN       Iquique  NaN  NaN   Confirmado         NaN
# 1                NaN       Iquique  NaN  NaN   Confirmado         NaN
# 2                NaN       Iquique  NaN  NaN   Confirmado         NaN
# 3                NaN       Iquique  NaN  NaN   Confirmado         NaN
# 4                NaN       Iquique  NaN  NaN   Confirmado         NaN
# ...              ...           ...  ...  ...          ...         ...
# 5567             NaN  No Informado  NaN  NaN   Recuperado         NaN
# 5568             NaN  No Informado  NaN  NaN   Recuperado         NaN
# 5569             NaN  No Informado  NaN  NaN   Recuperado         NaN
# 5570             NaN  No Informado  NaN  NaN   Recuperado         NaN
# 5571             NaN  No Informado  NaN  NaN   Recuperado         NaN
#
#       lon_comuna
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN
# ...          ...
# 5567         NaN
# 5568         NaN
# 5569         NaN
# 5570         NaN
# 5571         NaN
#
# [5572 rows x 14 columns]

# %%
aux = pd.read_csv("GrupoControl/covid19_chile.csv")
del aux["Unnamed: 14"]
del aux["Unnamed: 15"]
del aux["Unnamed: 16"]
aux.to_csv("GrupoControl/covid19_chile.csv", index=False)

# %%
aux
# Out:
#    ID       Fecha  Region_Numero   País    Region        Sexo  Edad  \
# 0   1  23-03-2020            1.0  Chile  Tarapacá   Masculino  47.0
# 1   2  23-03-2020            1.0  Chile  Tarapacá  Masculino   31.0
#
#    Centro_de_Salud   Comuna  lat  lon Tipo_de_caso  lat_comuna  lon_comuna
# 0              NaN  Iquique  NaN  NaN   Confirmado         NaN         NaN
# 1              NaN  Iquique  NaN  NaN   Confirmado         NaN         NaN
